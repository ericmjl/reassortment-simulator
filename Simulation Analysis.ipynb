# %%
import pickle as pkl
import pandas as pd

# %matplotlib inline

# %%
! echo $PATH
# Out:
# /Users/ericmjl/anaconda/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/X11/bin:/Library/TeX/texbin:/Library/Tex:/Users/ericmjl/anaconda/bin/pypy/bin/:/Users/ericmjl/anaconda/bin/pypy3/bin/

# %%
! pypy3 simulation.py
# Out:
# 5.074505090713501

# %%
with open('results/simulation.pkl', 'rb') as f:
    results = pkl.load(f)

# %%
data = pd.DataFrame(results)

# %%
data.columns
# Out:
# Index(['n_blue_immune', 'n_blue_virus', 'n_contacts', 'n_immune', 'n_infected',
#        'n_mixed', 'n_original', 'n_red_immune', 'n_red_virus', 'n_uninfected'],
#       dtype='object')

# %%
# Plot hosts
data[['n_blue_immune', 'n_red_immune', 'n_immune']].plot()

# %%
# Plot viruses.
data[['n_blue_virus', 'n_red_virus', 'n_mixed']].plot()

# %%
data[['n_contacts']].plot()
